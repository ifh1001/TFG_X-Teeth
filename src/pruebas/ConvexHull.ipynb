# %% [markdown]
# # **DETECCIÓN DE BORDES CON CONVEX HULL**
#
# ## Realizado por Ismael Franco Hernando
#
# Este notebook busca obtener los puntos del borde de una imagen que contiene un fondo blanco y una máscara de la imagen de un nervio o diente, y finalmente guardarlos en su correspondiente archivo JSON. Para ello se usará el algoritmo convex hull.
#
# Además, en caso de estar ejecutándose en Google Colab, se pueden incluir todos los JSON en un ZIP para poder descargarlos de forma más cómoda.

# %% [markdown]
# #### Imports

# %%
import cv2
import os
import json
import shutil
import zipfile
import numpy as np
from google.colab.patches import cv2_imshow

# %% [markdown]
# #### Función que realiza Convex Hull

# %%
# Método encargado de aplicar el algoritmo convex hull a un conjunto de
# imágenes.
#
# Parámetros:
#  - fotos: diccionario con las rutas de las imágenes a las que se desea aplicar
#           el convex hull.
#  - dibujar: True en caso de que se quiera dibujar la imagen con el área del
#             convex hull obtenido.
#  - bordes: True en caso de que se quiera dibujar el borde de los puntos
#            unidos, False en caso de que solo se quieran dibujar los puntos.
# Return:
#  - diccionario: contiene el par imagen, conjuntos de puntos del convex hull.
def convex_hull(fotos, dibujar=False, bordes=True):    
    # Diccionario formado por el nombre de la imagen como clave y en el valor
    # estaran los puntos de su controno
    diccionario = {}
    for f in fotos:
        ruta = f.split("/")
        # Cargamos la imagen
        foto = cv2.imread(f)
        # La pasamos a escalas de grises
        escala_grises = cv2.cvtColor(foto, cv2.COLOR_BGR2GRAY)
        # Obtenemos las partes deseadas (máscara azul)
        reequilibrio, partes = cv2.threshold(escala_grises, 200, 255, 4)
        # Obtenemos los contornos
        contornos, jerarquia = cv2.findContours(partes, cv2.RETR_TREE,
                                                cv2.CHAIN_APPROX_SIMPLE)

        if len(contornos) == 1:
            diccionario[ruta[1]] = contornos[0]

        if dibujar:
            print("La imagen", f, "tiene", len(contornos), "contorno")
            # Calculamos el convexhull de cada contorno y lo añadimos a la
            # imagen original
            for i in range(len(contornos)):
                convex_hull = cv2.convexHull(contornos[i])
                if bordes:
                    # Dibujar bordes
                    cv2.drawContours(foto, [convex_hull], -1, (0, 0, 255), 2)
                else:
                    # Dibujar puntos
                    cv2.drawContours(foto, convex_hull, -1, (0, 0, 255), 5)

            cv2_imshow(foto)
    return diccionario

# %% [markdown]
# #### Dientes

# %%
# Guardamos las rutas de los dientes
dientes = []
for fichero in os.listdir("dientes/"):
    if fichero.endswith('.png'):
        dientes.append("dientes/"+fichero)

# %%
diccionario_dientes = convex_hull(dientes, dibujar=True)
# Out:
# La imagen dientes/Caso03_2.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=473x613 at 0x7F3D97719BD0>
# La imagen dientes/Caso07_2.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=472x615 at 0x7F3D977198D0>
# La imagen dientes/Caso04_1.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=463x601 at 0x7F3D97719210>
# La imagen dientes/Caso10_2.png tiene 2 contorno
# <PIL.Image.Image image mode=RGB size=465x605 at 0x7F3D97719DD0>
# La imagen dientes/Caso09_1.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=645x858 at 0x7F3D977198D0>
# La imagen dientes/Caso04_2.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=463x601 at 0x7F3D97719710>
# La imagen dientes/Caso10_0.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=465x605 at 0x7F3D977192D0>
# La imagen dientes/Caso03_0.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=473x613 at 0x7F3D97719B10>
# La imagen dientes/Caso05_0.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=469x608 at 0x7F3D97719F50>
# La imagen dientes/Caso08_1.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=469x604 at 0x7F3D97719E90>
# La imagen dientes/Caso05_2.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=469x608 at 0x7F3D977193D0>
# La imagen dientes/Caso06_1.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=464x604 at 0x7F3D97719AD0>
# La imagen dientes/Caso07_1.png tiene 2 contorno
# <PIL.Image.Image image mode=RGB size=472x615 at 0x7F3D97719150>
# La imagen dientes/Caso03_1.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=473x613 at 0x7F3D97708090>
# La imagen dientes/Caso09_0.png tiene 6 contorno
# <PIL.Image.Image image mode=RGB size=645x858 at 0x7F3D9770F1D0>
# La imagen dientes/Caso10_1.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=465x605 at 0x7F3D9770FA50>
# La imagen dientes/Caso09_2.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=645x858 at 0x7F3D9770F0D0>
# La imagen dientes/Caso08_0.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=469x604 at 0x7F3D9770FE90>
# La imagen dientes/Caso06_2.png tiene 2 contorno
# <PIL.Image.Image image mode=RGB size=464x604 at 0x7F3D9770F250>
# La imagen dientes/Caso08_2.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=469x604 at 0x7F3D9770F210>
# La imagen dientes/Caso04_0.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=463x601 at 0x7F3D9770FC10>
# La imagen dientes/Caso06_0.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=464x604 at 0x7F3D9770F390>
# La imagen dientes/Caso05_1.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=469x608 at 0x7F3D9776ECD0>
# La imagen dientes/Caso07_0.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=472x615 at 0x7F3D9770F5D0>

# %% [markdown]
# #### Nervios

# %%
# Guardamos las rutas de los nervios
nervios = []
for fichero in os.listdir("nervios/"):
    if fichero.endswith('.png'):
        nervios.append("nervios/"+fichero)

# %%
diccionario_nervios = convex_hull(nervios, dibujar=True)
# Out:
# La imagen nervios/Caso08_1.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=469x604 at 0x7FB504E5BAD0>
# La imagen nervios/Caso03_0.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=473x613 at 0x7FB504E61D90>
# La imagen nervios/Caso01_2.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=476x621 at 0x7FB504E61A90>
# La imagen nervios/Caso06_0.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=464x604 at 0x7FB504E61E90>
# La imagen nervios/Caso01_1.png tiene 2 contorno
# <PIL.Image.Image image mode=RGB size=476x621 at 0x7FB504E61A90>
# La imagen nervios/Caso02_2.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=474x631 at 0x7FB504E5BD10>
# La imagen nervios/Caso03_2.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=473x613 at 0x7FB504E61A90>
# La imagen nervios/Caso06_1.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=464x604 at 0x7FB504E61C90>
# La imagen nervios/Caso05_2.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=469x608 at 0x7FB504E61410>
# La imagen nervios/Caso05_0.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=469x608 at 0x7FB504E61410>
# La imagen nervios/Caso07_1.png tiene 2 contorno
# <PIL.Image.Image image mode=RGB size=472x615 at 0x7FB504E61FD0>
# La imagen nervios/Caso02_1.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=474x631 at 0x7FB504E61F50>
# La imagen nervios/Caso09_0.png tiene 3 contorno
# <PIL.Image.Image image mode=RGB size=645x858 at 0x7FB504E614D0>
# La imagen nervios/Caso04_2.png tiene 3 contorno
# <PIL.Image.Image image mode=RGB size=463x601 at 0x7FB504E670D0>
# La imagen nervios/Caso08_0.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=469x604 at 0x7FB504E670D0>
# La imagen nervios/Caso06_2.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=464x604 at 0x7FB504E67090>
# La imagen nervios/Caso05_1.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=469x608 at 0x7FB504E670D0>
# La imagen nervios/Caso02_0.png tiene 2 contorno
# <PIL.Image.Image image mode=RGB size=474x631 at 0x7FB504E67090>
# La imagen nervios/Caso04_1.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=463x601 at 0x7FB504E67050>
# La imagen nervios/Caso01_0.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=476x621 at 0x7FB504E67090>
# La imagen nervios/Caso04_0.png tiene 2 contorno
# <PIL.Image.Image image mode=RGB size=463x601 at 0x7FB504E67150>
# La imagen nervios/Caso10_2.png tiene 2 contorno
# <PIL.Image.Image image mode=RGB size=465x605 at 0x7FB504E67190>
# La imagen nervios/Caso07_2.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=472x615 at 0x7FB504E61E90>
# La imagen nervios/Caso07_0.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=472x615 at 0x7FB504E61310>
# La imagen nervios/Caso10_1.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=465x605 at 0x7FB504E61E90>
# La imagen nervios/Caso10_0.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=465x605 at 0x7FB504E61F10>
# La imagen nervios/Caso09_2.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=645x858 at 0x7FB504E61C90>
# La imagen nervios/Caso09_1.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=645x858 at 0x7FB504E5B690>
# La imagen nervios/Caso03_1.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=473x613 at 0x7FB504E5B210>
# La imagen nervios/Caso08_2.png tiene 1 contorno
# <PIL.Image.Image image mode=RGB size=469x604 at 0x7FB504E61F90>

# %% [markdown]
# #### Crear JSON

# %%
# Método encargado de obtener los puntos del convex hull de una imagen.
#
# Parámetros:
#  - foto: foto de la que se quieren obtener los puntos.
#  - diccionario: diccionario que contiene el valor de los puntos del convex
#                 hull de todas las imágenes.
# Return:
#  - x, y: listas de cada eje que contienen los puntos del convex hull.
def obtiene_puntos(foto, diccionario):
    x = []
    y = []
    for i in range(len(diccionario[foto])):
        x.append(int(diccionario[foto][i][0][0]))
        y.append(int(diccionario[foto][i][0][1]))

    return x, y

# %%
# Método encargado de inicializar el JSON de una imagen, añadiendo los puntos
# del borde en cada eje y su nombre.
#
# Parámetros:
#  - foto: foto de la que se quiere inicializar el JSON.
#  - puntos_x: puntos del borde en el eje X.
#  - puntos_y: puntos del borde en el eje Y.
# Return:
#  - datos: diccionario con todos los datos añadidos para poder convertirlo a
#           JSON.
def inicializa_JSON(foto, puntos_x, puntos_y):
    atributos = {}
    atributos["shape_attributes"] = {}
    atributos["shape_attributes"]["all_points_x"] = puntos_x
    atributos["shape_attributes"]["all_points_y"] = puntos_y

    datos = {}
    datos[foto] = {}
    datos[foto]["filename"] = foto
    datos[foto]["regions"] = []
    datos[foto]["regions"].append(atributos)

    return datos

# %%
# Método encargado de crear los JSON de las imágenes.
#
# Parámetros:
#  - diccionario_dientes: diccionario con las imágenes y los valores del convex
#                         hull del diente.
#  - diccionario_nervios: diccionario con las imágenes y los valores del convex
#                         hull del nervio.
def crea_JSON(diccionario_dientes, diccionario_nervios):
    # Creamos el directorio donde se guardan los JSON
    if not os.path.isdir('final/'):
        os.makedirs('final/', exist_ok=True)

    # Obtenemos el nombre de todas las imágenes
    claves_dientes = list(diccionario_dientes.keys())
    claves_nervios = list(diccionario_nervios.keys())

    # Nos quedamos con aquellas imágenes que tienen el convex hull correcto tanto 
    # para el diente como para el nervio
    fotos_buenas = list(set(claves_dientes) & set(claves_nervios))

    #Creamos el JSON de cada imágen del diente y del nervio
    for f in fotos_buenas:
        puntos_x_diente, puntos_y_diente = obtiene_puntos(f,
                                                          diccionario_dientes)
        archivo = inicializa_JSON(f, puntos_x_diente, puntos_y_diente)
        with open('final/'+f[:-4]+'_1.json', 'w') as fichero:
            json.dump(archivo, fichero)

        puntos_x_nervio, puntos_y_nervio = obtiene_puntos(f,
                                                          diccionario_nervios)
        archivo = inicializa_JSON(f, puntos_x_nervio, puntos_y_nervio)
        with open('final/'+f[:-4]+'_2.json', 'w') as fichero:
            json.dump(archivo, fichero)

        shutil.copy(r'reales/'+f[:-4]+'.png', r'final/')

# %%
crea_JSON(diccionario_dientes, diccionario_nervios)

# %% [markdown]
# #### Crear ZIP para descargar de Google Colab

# %%
lista_ficheros = []
for fichero in os.listdir("final/"):
    lista_ficheros.append("final/"+fichero)

# %%
with zipfile.ZipFile('final.zip', 'w') as zip:
    for fich in lista_ficheros:
        zip.write(fich)
zip.close()
