# %% [markdown]
# # **Detección de Bordes en Dientes y Nervios, con Skimage y CV2**
#
# ## Realizado por Ismael Franco Hernando

# %% [markdown]
# ### Imports

# %%
import cv2
import os
import json
import shutil
import zipfile
import matplotlib.pyplot as plt
import numpy as np
from skimage import feature, io
from skimage.color import rgb2gray
from skimage.util import img_as_ubyte
from google.colab.patches import cv2_imshow

# %% [markdown]
# ### Añade borde blanco

# %%
def borde_blanco(dic):
    for d in dic:
        foto = cv2.imread(d)
        ancho = foto.shape[1]
        alto = foto.shape[0]

        # Se añade tres filas blancas en la parte superior e inferior
        for i in range(ancho):
            foto[0][i] = (255, 255, 255)
            foto[1][i] = (255, 255, 255)
            foto[2][i] = (255, 255, 255)
            foto[alto-1][i] = (255, 255, 255)
            foto[alto-2][i] = (255, 255, 255)
            foto[alto-3][i] = (255, 255, 255)

        # Se añaden tres columnas blancas a cada imagen
        for i in range(alto):
            foto[i][0] = (255, 255, 255)
            foto[i][1] = (255, 255, 255)
            foto[i][2] = (255, 255, 255)
            foto[i][ancho-1] = (255, 255, 255)
            foto[i][ancho-2] = (255, 255, 255)
            foto[i][ancho-3] = (255, 255, 255)

    cv2.imwrite(d, foto)

# %%
dientes = []
for fichero in os.listdir("dientes/"):
    if fichero.endswith('.png'):
        dientes.append("dientes/"+fichero)

# %%
borde_blanco(dientes)

# %%
nervios = []
for fichero in os.listdir("nervios/"):
    if fichero.endswith('.png'):
        nervios.append("nervios/"+fichero)

# %%
borde_blanco(nervios)

# %% [markdown]
# ### Detección borde con Skimage

# %%
# Método encargado de obtener los puntos del convex hull de una imagen.
#
# Parámetros:
#  - dic: .
#  - salida: .
#  - mostrar: .
#  - sig: .
def detecta_borde_skimage(dic, salida, mostrar=False, sig=1):
    if not os.path.isdir(salida):
        os.makedirs(salida, exist_ok=True)

    for d in dic:
        imagen = io.imread(d)
        ruta = d.split("/")
        gris = rgb2gray(imagen)
        borde = feature.canny(gris, sigma=sig)
        if mostrar:
            plt.imshow(borde)
            plt.axis('off')
            plt.show()
        borde = img_as_ubyte(borde)
        io.imsave(salida+ruta[1], borde)

# %%
detecta_borde_skimage(dientes, 'dientes_sk/', mostrar=True, sig=4)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso05_2.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso05_1.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso08_2.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso03_2.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso03_0.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso03_1.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso04_2.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso06_2.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso05_0.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso09_0.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso07_0.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso09_2.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso10_0.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso04_1.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso02_2.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso01_1.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso01_0.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso09_1.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso06_0.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso08_0.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso02_0.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso02_1.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso06_1.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso04_0.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso07_2.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso07_1.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso10_2.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso01_2.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso08_1.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: dientes_sk/Caso10_1.png is a low contrast image
#   from ipykernel import kernelapp as app

# %%
detecta_borde_skimage(nervios,'nervios_sk/', mostrar=True, sig=3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso05_2.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso05_1.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso08_2.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso03_2.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso03_0.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso03_1.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso04_2.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso06_2.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso05_0.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso09_0.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso07_0.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso09_2.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso10_0.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso04_1.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso02_2.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso01_1.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso01_0.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso09_1.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso06_0.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso08_0.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso02_0.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso02_1.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso06_1.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso04_0.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso07_2.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso07_1.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso10_2.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso01_2.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso08_1.png is a low contrast image
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: nervios_sk/Caso10_1.png is a low contrast image
#   from ipykernel import kernelapp as app

# %% [markdown]
# ### Obtenemos puntos con CV2

# %%
def obtener_puntos(fotos, dibujar=False, bordes=True):
  diccionario={} #Diccionario fomado por el nombre de la imagen como clave y en el valor estaran los puntos de su controno
  for f in fotos:  
    ruta=f.split("/")
    foto = cv2.imread(f) #cargamos la imagen    
    escala_grises = cv2.cvtColor(foto, cv2.COLOR_BGR2GRAY) #La pasamos a escalas de grises  

    reequilibrio, partes = cv2.threshold(escala_grises, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_TRIANGLE) #Obtenemos las partes deseadas (umbrales de color) 

    #Obtenemos los contornos
    contornos, jerarquia= cv2.findContours(partes, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    areas=[]
    for c in contornos:
      areas.append(cv2.contourArea(c))    
    areas=np.array(areas)
    area_min=areas.max()

    for c in contornos:
      area = cv2.contourArea(c)      
      if area == area_min:        
        diccionario[ruta[1]]=c
        if bordes:
          cv2.drawContours(foto, [c], 0, (0, 0, 255), 2)
        else:
          cv2.drawContours(foto, c, -1, (0, 0, 255), 2)

    if dibujar:
      print("Imagen",ruta[1])
      cv2_imshow(foto)
    
  return diccionario

# %%
dientes_sk = []
for fichero in os.listdir("dientes_sk/"):
    if fichero.endswith('.png'):
        dientes_sk.append("dientes_sk/"+fichero)

# %%
diccionario_dientes = obtener_puntos(dientes_sk, dibujar=True)
# Out:
# Imagen Caso05_2.png
# <PIL.Image.Image image mode=RGB size=472x612 at 0x7F773EB6ED50>
# Imagen Caso05_1.png
# <PIL.Image.Image image mode=RGB size=472x612 at 0x7F773E9D2110>
# Imagen Caso08_2.png
# <PIL.Image.Image image mode=RGB size=470x608 at 0x7F773E9D2D50>
# Imagen Caso03_2.png
# <PIL.Image.Image image mode=RGB size=478x616 at 0x7F773E9E3550>
# Imagen Caso03_0.png
# <PIL.Image.Image image mode=RGB size=478x616 at 0x7F773E9D21D0>
# Imagen Caso03_1.png
# <PIL.Image.Image image mode=RGB size=478x616 at 0x7F773E9E3250>
# Imagen Caso04_2.png
# <PIL.Image.Image image mode=RGB size=464x604 at 0x7F773E9E3A10>
# Imagen Caso06_2.png
# <PIL.Image.Image image mode=RGB size=470x608 at 0x7F773E9E38D0>
# Imagen Caso05_0.png
# <PIL.Image.Image image mode=RGB size=472x612 at 0x7F773E9E3710>
# Imagen Caso09_0.png
# <PIL.Image.Image image mode=RGB size=874x1156 at 0x7F773E9E3AD0>
# Imagen Caso07_0.png
# <PIL.Image.Image image mode=RGB size=470x616 at 0x7F773E9E3710>
# Imagen Caso09_2.png
# <PIL.Image.Image image mode=RGB size=874x1156 at 0x7F773E9E3650>
# Imagen Caso10_0.png
# <PIL.Image.Image image mode=RGB size=468x608 at 0x7F773E9E37D0>
# Imagen Caso04_1.png
# <PIL.Image.Image image mode=RGB size=464x604 at 0x7F773E9E39D0>
# Imagen Caso02_2.png
# <PIL.Image.Image image mode=RGB size=474x632 at 0x7F773E9E3D50>
# Imagen Caso01_1.png
# <PIL.Image.Image image mode=RGB size=476x620 at 0x7F773E9E3610>
# Imagen Caso01_0.png
# <PIL.Image.Image image mode=RGB size=476x620 at 0x7F773E9E3E90>
# Imagen Caso09_1.png
# <PIL.Image.Image image mode=RGB size=874x1156 at 0x7F773E9E38D0>
# Imagen Caso06_0.png
# <PIL.Image.Image image mode=RGB size=470x608 at 0x7F773E9E3D10>
# Imagen Caso08_0.png
# <PIL.Image.Image image mode=RGB size=470x608 at 0x7F773E9E3550>
# Imagen Caso02_0.png
# <PIL.Image.Image image mode=RGB size=474x632 at 0x7F773E9E3650>
# Imagen Caso02_1.png
# <PIL.Image.Image image mode=RGB size=474x632 at 0x7F773E9E3E90>
# Imagen Caso06_1.png
# <PIL.Image.Image image mode=RGB size=470x608 at 0x7F773E9E3BD0>
# Imagen Caso04_0.png
# <PIL.Image.Image image mode=RGB size=464x604 at 0x7F773E9E3C90>
# Imagen Caso07_2.png
# <PIL.Image.Image image mode=RGB size=470x616 at 0x7F773E9E3FD0>
# Imagen Caso07_1.png
# <PIL.Image.Image image mode=RGB size=470x616 at 0x7F773E9BE050>
# Imagen Caso10_2.png
# <PIL.Image.Image image mode=RGB size=468x608 at 0x7F773E9E3AD0>
# Imagen Caso01_2.png
# <PIL.Image.Image image mode=RGB size=476x620 at 0x7F773E9E3510>
# Imagen Caso08_1.png
# <PIL.Image.Image image mode=RGB size=470x608 at 0x7F773E9E3E10>
# Imagen Caso10_1.png
# <PIL.Image.Image image mode=RGB size=468x608 at 0x7F773E9E3F90>

# %%
nervios_sk = []
for fichero in os.listdir("nervios_sk/"):
    if fichero.endswith('.png'):
        nervios_sk.append("nervios_sk/"+fichero)

# %%
diccionario_nervios = obtener_puntos(nervios_sk, dibujar=True)
# Out:
# Imagen Caso05_2.png
# <PIL.Image.Image image mode=RGB size=472x612 at 0x7F773E9BE650>
# Imagen Caso05_1.png
# <PIL.Image.Image image mode=RGB size=472x612 at 0x7F773E9E3450>
# Imagen Caso08_2.png
# <PIL.Image.Image image mode=RGB size=470x608 at 0x7F773E9E3A50>
# Imagen Caso03_2.png
# <PIL.Image.Image image mode=RGB size=478x616 at 0x7F773E9E3C50>
# Imagen Caso03_0.png
# <PIL.Image.Image image mode=RGB size=478x616 at 0x7F773E9E3450>
# Imagen Caso03_1.png
# <PIL.Image.Image image mode=RGB size=478x616 at 0x7F773E9BE790>
# Imagen Caso04_2.png
# <PIL.Image.Image image mode=RGB size=464x604 at 0x7F773E9BEFD0>
# Imagen Caso06_2.png
# <PIL.Image.Image image mode=RGB size=470x608 at 0x7F773E9BEF50>
# Imagen Caso05_0.png
# <PIL.Image.Image image mode=RGB size=472x612 at 0x7F773E9BEED0>
# Imagen Caso09_0.png
# <PIL.Image.Image image mode=RGB size=874x1156 at 0x7F773E9D2790>
# Imagen Caso07_0.png
# <PIL.Image.Image image mode=RGB size=470x616 at 0x7F773E9E3910>
# Imagen Caso09_2.png
# <PIL.Image.Image image mode=RGB size=874x1156 at 0x7F773E9E3FD0>
# Imagen Caso10_0.png
# <PIL.Image.Image image mode=RGB size=468x608 at 0x7F773E9BE690>
# Imagen Caso04_1.png
# <PIL.Image.Image image mode=RGB size=464x604 at 0x7F773E9DA3D0>
# Imagen Caso02_2.png
# <PIL.Image.Image image mode=RGB size=474x632 at 0x7F773E9BEF90>
# Imagen Caso01_1.png
# <PIL.Image.Image image mode=RGB size=476x620 at 0x7F773E9DA150>
# Imagen Caso01_0.png
# <PIL.Image.Image image mode=RGB size=476x620 at 0x7F773E9DA150>
# Imagen Caso09_1.png
# <PIL.Image.Image image mode=RGB size=874x1156 at 0x7F773E9DA150>
# Imagen Caso06_0.png
# <PIL.Image.Image image mode=RGB size=470x608 at 0x7F773E9DA650>
# Imagen Caso08_0.png
# <PIL.Image.Image image mode=RGB size=470x608 at 0x7F773E9DA790>
# Imagen Caso02_0.png
# <PIL.Image.Image image mode=RGB size=474x632 at 0x7F773E9DA690>
# Imagen Caso02_1.png
# <PIL.Image.Image image mode=RGB size=474x632 at 0x7F773E9DA550>
# Imagen Caso06_1.png
# <PIL.Image.Image image mode=RGB size=470x608 at 0x7F773E9DA410>
# Imagen Caso04_0.png
# <PIL.Image.Image image mode=RGB size=464x604 at 0x7F773E9DA150>
# Imagen Caso07_2.png
# <PIL.Image.Image image mode=RGB size=470x616 at 0x7F773E9BE650>
# Imagen Caso07_1.png
# <PIL.Image.Image image mode=RGB size=470x616 at 0x7F773E9DA2D0>
# Imagen Caso10_2.png
# <PIL.Image.Image image mode=RGB size=468x608 at 0x7F773E9BE490>
# Imagen Caso01_2.png
# <PIL.Image.Image image mode=RGB size=476x620 at 0x7F773E9DA310>
# Imagen Caso08_1.png
# <PIL.Image.Image image mode=RGB size=470x608 at 0x7F773E9E32D0>
# Imagen Caso10_1.png
# <PIL.Image.Image image mode=RGB size=468x608 at 0x7F773E9E3910>

# %% [markdown]
# ### Generar JSON

# %%
# Método encargado de obtener los puntos del borde de una imagen.
#
# Parámetros:
#  - foto: foto de la que se quieren obtener los puntos.
#  - diccionario: diccionario que contiene el valor de los puntos del borde
#                 de todas las imágenes.
# Return:
#  - x, y: listas de cada eje que contienen los puntos del borde.
def obtiene_puntos(foto, diccionario):
    x = []
    y = []
    for i in range(len(diccionario[foto])):
        x.append(int(diccionario[foto][i][0][0]))
        y.append(int(diccionario[foto][i][0][1]))

    return x, y

# %%
# Método encargado de inicializar el JSON de una imagen, añadiendo los puntos
# del borde en cada eje y su nombre.
#
# Parámetros:
#  - foto: foto de la que se quiere inicializar el JSON.
#  - puntos_x: puntos del borde en el eje X.
#  - puntos_y: puntos del borde en el eje Y.
# Return:
#  - datos: diccionario con todos los datos añadidos para poder convertirlo a
#           JSON.
def inicializa_JSON(foto, puntos_x, puntos_y):
    atributos = {}
    atributos["shape_attributes"] = {}
    atributos["shape_attributes"]["all_points_x"] = puntos_x
    atributos["shape_attributes"]["all_points_y"] = puntos_y

    datos = {}
    datos[foto] = {}
    datos[foto]["filename"] = foto
    datos[foto]["regions"] = []
    datos[foto]["regions"].append(atributos)

    return datos

# %%
# Método encargado de crear los JSON de las imágenes.
#
# Parámetros:
#  - diccionario_dientes: diccionario con las imágenes y los valores del borde
#                         del diente.
#  - diccionario_nervios: diccionario con las imágenes y los valores del borde
#                         del nervio.
def crea_JSON(diccionario_dientes, diccionario_nervios):
    # Creamos el directorio donde se guardan los JSON
    if not os.path.isdir('final/'):
        os.makedirs('final/', exist_ok=True)

    # Obtenemos el nombre de todas las imágenes
    claves_dientes = list(diccionario_dientes.keys())
    claves_nervios = list(diccionario_nervios.keys())

    # Nos quedamos con aquellas imágenes que tienen el borde correcto tanto 
    # para el diente como para el nervio
    fotos_buenas = list(set(claves_dientes) & set(claves_nervios))

    #Creamos el JSON de cada imágen del diente y del nervio
    for f in fotos_buenas:
        puntos_x_diente, puntos_y_diente = obtiene_puntos(f,
                                                          diccionario_dientes)
        archivo = inicializa_JSON(f, puntos_x_diente, puntos_y_diente)
        with open('final/'+f[:-4]+'_1.json', 'w') as fichero:
            json.dump(archivo, fichero)

        puntos_x_nervio, puntos_y_nervio = obtiene_puntos(f,
                                                          diccionario_nervios)
        archivo = inicializa_JSON(f, puntos_x_nervio, puntos_y_nervio)
        with open('final/'+f[:-4]+'_2.json', 'w') as fichero:
            json.dump(archivo, fichero)

        shutil.copy(r'reales/'+f[:-4]+'.png', r'final/')

# %%
crea_JSON(diccionario_dientes, diccionario_nervios)

# %% [markdown]
# ### Crea ZIP

# %%
lista_ficheros = []
for fichero in os.listdir("final/"):
    lista_ficheros.append("final/"+fichero)

# %%
with zipfile.ZipFile('final.zip', 'w') as zip:
    for fich in lista_ficheros:
        zip.write(fich)
zip.close()
